# %%
pip install pyinstaller
# Out:
# ...
#   Obtaining dependency information for pyinstaller from https://files.pythonhosted.org/packages/7d/08/f43080614b3e8bce481d4dfd580e579497c7dcdaf87656d9d2ad912e5796/pyinstaller-6.11.1-py3-none-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for altgraph from https://files.pythonhosted.org/packages/4d/3f/3bc3f1d83f6e4a7fcb834d3720544ca597590425be5ba9db032b2bf322a2/altgraph-0.17.4-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pyinstaller-hooks-contrib>=2024.9 from https://files.pythonhosted.org/packages/23/46/f0654c01d3e16ee652e62dd59c8e80b67842d83d9c103d69d0654507954a/pyinstaller_hooks_contrib-2025.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pefile!=2024.8.26,>=2022.5.30 from https://files.pythonhosted.org/packages/55/26/d0ad8b448476d0a1e8d3ea5622dc77b916db84c6aa3cb1e1c0965af948fc/pefile-2023.2.7-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
# ...

# %%
# !pyinstaller main.py -F --onefile \
--add-data "C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Lib\\site-packages\\xgboost\\lib\\xgboost.dll;xgboost/lib" \
--add-data "C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Lib\\site-packages\\xgboost\\VERSION;xgboost" \
--add-data "C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Lib\\site-packages\\imblearn\\VERSION.txt;imblearn" \
--hidden-import matplotlib.backends.backend_pdf
# Out:
# 584 INFO: PyInstaller: 6.11.1, contrib hooks: 2025.0
# 585 INFO: Python: 3.13.1
# 628 INFO: Platform: Windows-10-10.0.19045-SP0
# 628 INFO: Python environment: C:\Users\sv24v923\PycharmProjects\ML_Predicting_framework\.venv
# 629 INFO: wrote C:\Users\sv24v923\PycharmProjects\ML_Predicting_framework\main.spec
# 637 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework',
#  'C:\\Program Files (x86)\\JetBrains\\PyCharm '
#  '2024.3.1\\plugins\\python-ce\\helpers\\pydev',
#  'C:\\Program Files (x86)\\JetBrains\\PyCharm '
#  '2024.3.1\\plugins\\python\\helpers-pro\\jupyter_debug',
#  'C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Scripts\\python313.zip',
#  'C:\\Users\\sv24v923\\AppData\\Local\\Programs\\Python\\Python313\\DLLs',
#  'C:\\Users\\sv24v923\\AppData\\Local\\Programs\\Python\\Python313\\Lib',
# ...

# %%
# !pyinstaller main.py -F --onefile --add-data "C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Lib\\site-packages\\xgboost\\lib\\xgboost.dll;xgboost/lib" --add-data "C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Lib\\site-packages\\xgboost\\VERSION;xgboost"
# Out:
# 526 INFO: PyInstaller: 6.11.1, contrib hooks: 2025.0
# 527 INFO: Python: 3.13.1
# 577 INFO: Platform: Windows-10-10.0.19045-SP0
# 577 INFO: Python environment: C:\Users\sv24v923\PycharmProjects\ML_Predicting_framework\.venv
# 579 INFO: wrote C:\Users\sv24v923\PycharmProjects\ML_Predicting_framework\main.spec
# 588 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework',
#  'C:\\Program Files (x86)\\JetBrains\\PyCharm '
#  '2024.3.1\\plugins\\python-ce\\helpers\\pydev',
#  'C:\\Program Files (x86)\\JetBrains\\PyCharm '
#  '2024.3.1\\plugins\\python\\helpers-pro\\jupyter_debug',
#  'C:\\Users\\sv24v923\\PycharmProjects\\ML_Predicting_framework\\.venv\\Scripts\\python313.zip',
#  'C:\\Users\\sv24v923\\AppData\\Local\\Programs\\Python\\Python313\\DLLs',
#  'C:\\Users\\sv24v923\\AppData\\Local\\Programs\\Python\\Python313\\Lib',
# ...

# %%
import pandas as pd
hdm = pd.read_csv('/users/genomics/marta/BLCA/HdM-BLCA-1/analysis/01_counts/TPMs_genenames.csv', index_col=0)

# %%
hdm.to_csv('/datasets/sergio/HdM-BLCA-1/TPMs_genenames.txt', sep = '\t')
# Out:
#    Tumor_Sample_Barcode RECIST Response     Sex  ECOG ECOG_under0  Age Smoker  \
# 1               BACI107     CR        R    male   1.0           N   81      Y
# 2               BACI109     SD      NaN  female   3.0           N   78      N
# 3               BACI110     PD       NR    male   NaN         NaN   41      Y
# 4               BACI111     PR        R    male   NaN         NaN   70      Y
# 5               BACI112     CR        R  female   2.0           N   71      N
# ..                  ...    ...      ...     ...   ...         ...  ...    ...
# 85              BACI210     PD       NR    male   1.0           N   66      Y
# 86              BACI211     PD       NR  female   2.0           N   77      Y
# 87              BACI212     PD       NR    male   2.0           N   85      Y
# 88              BACI217    NaN      NaN  female   NaN         NaN   87      Y
# 89              BACI219     PD       NR    male   NaN         NaN   53      Y
#
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv('/projects_eg/projects/lilian/Combined_data/6datasets_RNA+DNA/df_WES+RNA_response.csv', index_col=0)
